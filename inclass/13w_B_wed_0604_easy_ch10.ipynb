# %% [markdown]
# <a href="https://colab.research.google.com/github/soyoon-0118/2025-1-myclass-BDA/blob/main/inclass/13w_B_wed_0604_easy_ch10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ai7dnn/data
# Out:
# Cloning into 'data'...
# remote: Enumerating objects: 50, done.
# remote: Counting objects: 100% (50/50), done.
# remote: Compressing objects: 100% (48/48), done.
# remote: Total 50 (delta 12), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (50/50), 5.71 MiB | 5.15 MiB/s, done.
# Resolving deltas: 100% (12/12), done.

# %%
# !pip show konlpy
# Out:
# WARNING: Package(s) not found: konlpy

# %%
# !pip install konlpy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 96.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 494.1/494.1 kB 41.5 MB/s eta 0:00:00
# ...

# %%
# !pip show koreanize-matplotlib
# Out:
# WARNING: Package(s) not found: koreanize-matplotlib

# %%
# !pip install koreanize-matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 49.9 MB/s eta 0:00:00
# ...

# %%
import koreanize_matplotlib

# %%
# !pip show wordcloud
# Out:
# Name: wordcloud
# Version: 1.9.4
# Summary: A little word cloud generator
# Home-page: https://github.com/amueller/word_cloud
# Author:
# Author-email: Andreas Mueller <t3kcit+wordcloud@gmail.com>
# License: MIT License
# Location: /usr/local/lib/python3.11/dist-packages
# Requires: matplotlib, numpy, pillow
# Required-by:

# %%
# !find / -name NanumGothic.ttf
# Out:
# find: ‘/proc/65/task/65/net’: Invalid argument
# find: ‘/proc/65/net’: Invalid argument
# /usr/local/lib/python3.11/dist-packages/koreanize_matplotlib/fonts/NanumGothic.ttf

# %%
FONT_PATH = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'

# %%
f=open('data/speech_moon.txt', encoding='utf-8')
moon = f.read()
f.close()

# %%
moon
# Out:
# '정권교체 하겠습니다!\n  정치교체 하겠습니다!\n  시대교체 하겠습니다!\n  \n  ‘불비불명(不飛不鳴)’이라는 고사가 있습니다. 남쪽 언덕 나뭇가지에 앉아, 3년 동안 날지도 울지도 않는 새. 그러나 그 새는 한번 날면 하늘 끝까지 날고, 한번 울면 천지를 뒤흔듭니다.\n\n그 동안 정치와 거리를 둬 왔습니다. 그러나 암울한 시대가 저를 정치로 불러냈습니다. 더 이상 남쪽 나뭇가지에 머무를 수 없었습니다. 이제 저는 국민과 함께 높이 날고 크게 울겠습니다. 오늘 저는 제18대 대통령선거 출마를 국민 앞에 엄숙히 선언합니다.\n\n\n‘우리나라 대통령’이 되겠습니다.\n\n\n존경하는 국민 여러분!\n  \n  저는 대통령이 되겠습니다. 우리나라 대통령이 되겠습니다. 소수 특권층의 나라가 아니라 보통사람들이 주인인 ‘우리나라’, 네 편 내 편 편가르지 않고 함께 가는 우리나라, ‘우리’라는 말이 조금도 부끄럽지 않은, 진정한 ‘우리나라’의 대통령이 되겠습니다.\n\n지금까지 우리 보통사람들은 날지도 울지도 못하는 새였습니다. 나라의 주인으로 행세하지 못했고, 주인으로 대접받지 못했습니다. 나서서 말도 하지 못했습니다. 이제 몸을 일으켜 날아야 합니다. 당당하게 말하고 정치에 참여해야 합니다.\n\n제가 추구하는 ‘우리나라’는 정치인에게 맡겨놓는 나라가 아니라 시민이 직접 정치와 정책과정에 참여하는 나라입니다. 저는 시민과 동행하는 정치를 하고 싶습니다. 제가 추구하는 ‘우리나라’는 특권과 불평등의 나라가 아니라, 보통사람들이 함께 기회를 가지는 공평하고 정의로운 나라입니다.\n\n이제 권력과 돈을 가진 집단이 나라를 그들 마음대로 움직이던 시대는 끝났습니다. 힘없는 사람들에게 끝없이 희생을 강요하던 낡은 경제, 낡은 정치, 낡은 권력도 모두 끝났습니다. 오늘 저 문재인은 우리나라를 우리 모두의 나라로 선언합니다.\n\n국민이 모두 아픕니다.\n\n제가 높이 날고 크게 울겠다고 결심한 이유는 보통사람들의 삶이 너무 고달프고, 우리가 처한 현실이 너무도 
# ...

# %%
import re

moon = re.sub('[^가-힣]',' ',moon)
moon
# Out:
# '정권교체 하겠습니다    정치교체 하겠습니다    시대교체 하겠습니다        불비불명       이라는 고사가 있습니다  남쪽 언덕 나뭇가지에 앉아   년 동안 날지도 울지도 않는 새  그러나 그 새는 한번 날면 하늘 끝까지 날고  한번 울면 천지를 뒤흔듭니다   그 동안 정치와 거리를 둬 왔습니다  그러나 암울한 시대가 저를 정치로 불러냈습니다  더 이상 남쪽 나뭇가지에 머무를 수 없었습니다  이제 저는 국민과 함께 높이 날고 크게 울겠습니다  오늘 저는 제  대 대통령선거 출마를 국민 앞에 엄숙히 선언합니다     우리나라 대통령 이 되겠습니다    존경하는 국민 여러분       저는 대통령이 되겠습니다  우리나라 대통령이 되겠습니다  소수 특권층의 나라가 아니라 보통사람들이 주인인  우리나라   네 편 내 편 편가르지 않고 함께 가는 우리나라   우리 라는 말이 조금도 부끄럽지 않은  진정한  우리나라 의 대통령이 되겠습니다   지금까지 우리 보통사람들은 날지도 울지도 못하는 새였습니다  나라의 주인으로 행세하지 못했고  주인으로 대접받지 못했습니다  나서서 말도 하지 못했습니다  이제 몸을 일으켜 날아야 합니다  당당하게 말하고 정치에 참여해야 합니다   제가 추구하는  우리나라 는 정치인에게 맡겨놓는 나라가 아니라 시민이 직접 정치와 정책과정에 참여하는 나라입니다  저는 시민과 동행하는 정치를 하고 싶습니다  제가 추구하는  우리나라 는 특권과 불평등의 나라가 아니라  보통사람들이 함께 기회를 가지는 공평하고 정의로운 나라입니다   이제 권력과 돈을 가진 집단이 나라를 그들 마음대로 움직이던 시대는 끝났습니다  힘없는 사람들에게 끝없이 희생을 강요하던 낡은 경제  낡은 정치  낡은 권력도 모두 끝났습니다  오늘 저 문재인은 우리나라를 우리 모두의 나라로 선언합니다   국민이 모두 아픕니다   제가 높이 날고 크게 울겠다고 결심한 이유는 보통사람들의 삶이 너무 고달프고  우리가 처한 현실이 너무도 엄중하기 때문입니다  근본적인 혁신  거대한
# ...

# %%
from konlpy.tag import Hannanum
han = Hannanum()
han.nouns(u'대한민국의 영토는 한반도와 그 부속도서로 한다')
# Out:
# ['대한민국', '영토', '한반도', '부속도서']

# %%
nouns = han.nouns(moon)
type(nouns)
# Out:
# list

# %%
len(nouns)
# Out:
# 1413

# %%
nouns[:10]
# Out:
# ['정권교체', '정치교체', '시대교체', '불비불명', '고사', '남쪽', '언덕', '나뭇가지', '년', '동안']

# %%
nouns[-10:]
# Out:
# ['마음', '길', '우리나라', '대통령', '우리', '모두', '주인', '진정한', '우리나라', '대통령']

# %%
import pandas as pd
df_word = pd.DataFrame({'word': nouns})
df_word
# Out:
#       word
# 0     정권교체
# 1     정치교체
# 2     시대교체
# 3     불비불명
# 4       고사
# ...    ...
# 1408    모두
# 1409    주인
# 1410   진정한
# 1411  우리나라
# 1412   대통령
#
# [1413 rows x 1 columns]

# %%
df_word.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1413 entries, 0 to 1412
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   word    1413 non-null   object
# dtypes: object(1)
# memory usage: 11.2+ KB

# %%
df_word['word'].value_counts()
# Out:
# word
# 저      22
# 일자리    19
# 나라     19
# 국민     18
# 우리     17
#        ..
# 경영      1
# 성       1
# 다수      1
# 군림      1
# 문       1
# Name: count, Length: 789, dtype: int64

# %%
df_word[df_word.word == '대통령']
# Out:
#      word
# 39    대통령
# 44    대통령
# 46    대통령
# 65    대통령
# 268   대통령
# 1051  대통령
# 1053  대통령
# 1071  대통령
# 1205  대통령
# 1347  대통령
# 1406  대통령
# 1412  대통령

# %%
df_word['len'] = df_word['word'].str.len()
df_word.head()
# Out:
#    word  len
# 0  정권교체    4
# 1  정치교체    4
# 2  시대교체    4
# 3  불비불명    4
# 4    고사    2

# %%
df_word[df_word.len >= 2]
# Out:
#       word  len
# 0     정권교체    4
# 1     정치교체    4
# 2     시대교체    4
# 3     불비불명    4
# 4       고사    2
# ...    ...  ...
# 1408    모두    2
# 1409    주인    2
# 1410   진정한    3
# 1411  우리나라    4
# 1412   대통령    3
#
# [1187 rows x 2 columns]

# %%
df_word.query('len >= 2')
# Out:
#       word  len
# 0     정권교체    4
# 1     정치교체    4
# 2     시대교체    4
# 3     불비불명    4
# 4       고사    2
# ...    ...  ...
# 1408    모두    2
# 1409    주인    2
# 1410   진정한    3
# 1411  우리나라    4
# 1412   대통령    3
#
# [1187 rows x 2 columns]

# %%
df = df_word.query('len >= 2')
df.sort_values(by='len')
# Out:
#           word  len
# 712         국민    2
# 1164        가사    2
# 1163        숙제    2
# 1162        평등    2
# 644         확대    2
# ...        ...  ...
# 707     평생학습체제    6
# 1268    군사대결지대    6
# 173     성적스트레스    6
# 978   고용영향평가제도    8
# 1055  국가일자리위원회    8
#
# [1187 rows x 2 columns]

# %%
df[df.word == '대통령']
# Out:
#      word  len
# 39    대통령    3
# 44    대통령    3
# 46    대통령    3
# 65    대통령    3
# 268   대통령    3
# 1051  대통령    3
# 1053  대통령    3
# 1071  대통령    3
# 1205  대통령    3
# 1347  대통령    3
# 1406  대통령    3
# 1412  대통령    3

# %%
df_freq = df.groupby('word', as_index=False) \
            .agg(n = ('word', 'count')) \
            .sort_values('n', ascending=False)
df_freq
# Out:
#      word   n
# 153    나라  19
# 462   일자리  19
# 116    국민  18
# 422    우리  17
# 198   대통령  12
# ..    ...  ..
# 278  북핵문제   1
# 279    분단   1
# 281    분야   1
# 283    분쟁   1
# 355    수천   1
#
# [710 rows x 2 columns]

# %%
df_freq[df_freq.word == '대통령']
# Out:
#     word   n
# 198  대통령  12

# %%
top20 = df_freq.head(20)
top20
# Out:
#      word   n
# 153    나라  19
# 462   일자리  19
# 116    국민  18
# 422    우리  17
# 198   대통령  12
# 202  대한민국  11
# 693    확대  11
# 525    정치  10
# 423  우리나라  10
# 304    사회   9
# 298    사람   9
# 332    성장   9
# 646    평화   8
# 266  복지국가   8
# 265    복지   8
# 308    산업   7
# 517    정부   7
# 609    추진   7
# 103    교육   6
# 339    세상   6

# %%
# %config InlineBackend.figure_format = 'retina'

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.barplot(top20, y='word', x='n', hue='word');

# %%
df_freq.head(5)
# Out:
#     word   n
# 153   나라  19
# 462  일자리  19
# 116   국민  18
# 422   우리  17
# 198  대통령  12

# %%
df_freq.set_index('word')
# Out:
#        n
# word
# 나라    19
# 일자리   19
# 국민    18
# 우리    17
# 대통령   12
# ...   ..
# 북핵문제   1
# 분단     1
# 분야     1
# 분쟁     1
# 수천     1
#
# [710 rows x 1 columns]

# %%
mydf = pd.DataFrame({'col1': [1, 2], 'col2': [0.5, 0.75]},
                    index= ['row1', 'row2'])
mydf
# Out:
#       col1  col2
# row1     1  0.50
# row2     2  0.75

# %%
mydf.to_dict()
# Out:
# {'col1': {'row1': 1, 'row2': 2}, 'col2': {'row1': 0.5, 'row2': 0.75}}

# %%
df_freq.set_index('word').to_dict()
# Out:
# {'n': {'나라': 19,
#   '일자리': 19,
#   '국민': 18,
#   '우리': 17,
#   '대통령': 12,
#   '대한민국': 11,
#   '확대': 11,
#   '정치': 10,
#   '우리나라': 10,
#   '사회': 9,
#   '사람': 9,
#   '성장': 9,
#   '평화': 8,
#   '복지국가': 8,
#   '복지': 8,
#   '산업': 7,
#   '정부': 7,
#   '추진': 7,
#   '교육': 6,
#   '세상': 6,
#   '경쟁': 6,
#   '보통사람들': 5,
#   '공평': 5,
#   '경제': 5,
#   '대통령의': 5,
#   '상생': 5,
#   '정규직': 5,
#   '정의': 4,
#   '결과': 4,
#   '사회적': 4,
#   '투자': 4,
#   '주인': 4,
#   '전환': 4,
#   '때문': 4,
#   '모델': 4,
#   '요구': 4,
#   '희망': 4,
#   '창출': 4,
#   '역사': 4,
#   '기회': 4,
#   '여성': 4,
#   '담쟁': 4,
#   '강화': 4,
#   '아래': 4,
#   '고통': 4,
#   '약자': 4,
#   '아이들': 4,
#   '중소기업': 4,
#   '공정': 3,
#   '문재인': 3,
#   '특권': 3,
#   '국가': 3,
#   '사람들': 3,
#   '노인': 3,
#   '변화': 3,
#   '비중': 3,
#   '교육혁신': 3,
#   '관계': 3,
#   '질서': 3,
#   '군대': 3,
#   '지원': 3,
#   '과도한': 3,
#   '권력': 3,
#   '부담': 3,
#   '그것': 3,
#   '지방': 3,
#   '국민들': 3,
#   '채택': 3,
#   '소수': 3,
#   '세계': 3,
#   '신산업': 3,
#   '시민': 3,
#   '개선': 3,
# ...

# %%
df_freq.set_index('word').to_dict()['n']
# Out:
# {'나라': 19,
#  '일자리': 19,
#  '국민': 18,
#  '우리': 17,
#  '대통령': 12,
#  '대한민국': 11,
#  '확대': 11,
#  '정치': 10,
#  '우리나라': 10,
#  '사회': 9,
#  '사람': 9,
#  '성장': 9,
#  '평화': 8,
#  '복지국가': 8,
#  '복지': 8,
#  '산업': 7,
#  '정부': 7,
#  '추진': 7,
#  '교육': 6,
#  '세상': 6,
#  '경쟁': 6,
#  '보통사람들': 5,
#  '공평': 5,
#  '경제': 5,
#  '대통령의': 5,
#  '상생': 5,
#  '정규직': 5,
#  '정의': 4,
#  '결과': 4,
#  '사회적': 4,
#  '투자': 4,
#  '주인': 4,
#  '전환': 4,
#  '때문': 4,
#  '모델': 4,
#  '요구': 4,
#  '희망': 4,
#  '창출': 4,
#  '역사': 4,
#  '기회': 4,
#  '여성': 4,
#  '담쟁': 4,
#  '강화': 4,
#  '아래': 4,
#  '고통': 4,
#  '약자': 4,
#  '아이들': 4,
#  '중소기업': 4,
#  '공정': 3,
#  '문재인': 3,
#  '특권': 3,
#  '국가': 3,
#  '사람들': 3,
#  '노인': 3,
#  '변화': 3,
#  '비중': 3,
#  '교육혁신': 3,
#  '관계': 3,
#  '질서': 3,
#  '군대': 3,
#  '지원': 3,
#  '과도한': 3,
#  '권력': 3,
#  '부담': 3,
#  '그것': 3,
#  '지방': 3,
#  '국민들': 3,
#  '채택': 3,
#  '소수': 3,
#  '세계': 3,
#  '신산업': 3,
#  '시민': 3,
#  '개선': 3,
#  '혁신': 3,
#  '혁명': 3,
#  '양극화': 3,
#  '원칙': 3,
#  '활용': 3,
#  '행복': 3,
#  '원전': 3,
# ...

# %%
dic_word = df_freq.set_index('word').to_dict()['n']
dic_word
# Out:
# {'나라': 19,
#  '일자리': 19,
#  '국민': 18,
#  '우리': 17,
#  '대통령': 12,
#  '대한민국': 11,
#  '확대': 11,
#  '정치': 10,
#  '우리나라': 10,
#  '사회': 9,
#  '사람': 9,
#  '성장': 9,
#  '평화': 8,
#  '복지국가': 8,
#  '복지': 8,
#  '산업': 7,
#  '정부': 7,
#  '추진': 7,
#  '교육': 6,
#  '세상': 6,
#  '경쟁': 6,
#  '보통사람들': 5,
#  '공평': 5,
#  '경제': 5,
#  '대통령의': 5,
#  '상생': 5,
#  '정규직': 5,
#  '정의': 4,
#  '결과': 4,
#  '사회적': 4,
#  '투자': 4,
#  '주인': 4,
#  '전환': 4,
#  '때문': 4,
#  '모델': 4,
#  '요구': 4,
#  '희망': 4,
#  '창출': 4,
#  '역사': 4,
#  '기회': 4,
#  '여성': 4,
#  '담쟁': 4,
#  '강화': 4,
#  '아래': 4,
#  '고통': 4,
#  '약자': 4,
#  '아이들': 4,
#  '중소기업': 4,
#  '공정': 3,
#  '문재인': 3,
#  '특권': 3,
#  '국가': 3,
#  '사람들': 3,
#  '노인': 3,
#  '변화': 3,
#  '비중': 3,
#  '교육혁신': 3,
#  '관계': 3,
#  '질서': 3,
#  '군대': 3,
#  '지원': 3,
#  '과도한': 3,
#  '권력': 3,
#  '부담': 3,
#  '그것': 3,
#  '지방': 3,
#  '국민들': 3,
#  '채택': 3,
#  '소수': 3,
#  '세계': 3,
#  '신산업': 3,
#  '시민': 3,
#  '개선': 3,
#  '혁신': 3,
#  '혁명': 3,
#  '양극화': 3,
#  '원칙': 3,
#  '활용': 3,
#  '행복': 3,
#  '원전': 3,
# ...

# %%
dic_word['대한민국']
# Out:
# 11

# %%
from wordcloud import WordCloud

wc = WordCloud(random_state = 1234,
               font_path = FONT_PATH,
               width = 600, height = 300,
               background_color = 'pink')

# %%
img_wc = wc.generate_from_frequencies(dic_word)

plt.axis('off')
plt.imshow(img_wc)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-48-a2f35efb1e10> in <cell line: 0>()
# ----> 1 img_wc = wc.generate_from_frequencies(dic_word)
#       2
#       3 plt.axis('off')
#       4 plt.imshow(img_wc)
#       5 plt.show()
#
# /usr/local/lib/python3.11/dist-packages/wordcloud/wordcloud.py in generate_from_frequencies(self, frequencies, max_font_size)
#     451                 font_size = self.height
#     452             else:
# --> 453                 self.generate_from_frequencies(dict(frequencies[:2]),
#     454                                                max_font_size=self.height)
#     455                 # find font sizes
#
# /usr/local/lib/python3.11/dist-packages/wordcloud/wordcloud.py in generate_from_frequencies(self, frequencies, max_font_size)
#     504                     break
#     505                 # try to find a position
# ...

# %% [markdown]
# ## 13주차 수업

# %%
from PIL import image
icon = image.open('data/cloud.png')

# %%
import numpy as np

img_wc = wc.generate_from_frequencies(dic_word)

plt.axis('off')
plt.imshow(img_wc)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-42-87240f4cd7d2> in <cell line: 0>()
#       1 import numpy as np
#       2
# ----> 3 img_wc = wc.generate_from_frequencies(dic_word)
#       4
#       5 plt.axis('off')
#
# /usr/local/lib/python3.11/dist-packages/wordcloud/wordcloud.py in generate_from_frequencies(self, frequencies, max_font_size)
#     451                 font_size = self.height
#     452             else:
# --> 453                 self.generate_from_frequencies(dict(frequencies[:2]),
#     454                                                max_font_size=self.height)
#     455                 # find font sizes
#
# /usr/local/lib/python3.11/dist-packages/wordcloud/wordcloud.py in generate_from_frequencies(self, frequencies, max_font_size)
#     504                     break
#     505                 # try to find a position
# ...

# %%
wc = WordCloud(random_state = 1234,
               font_path = FONT_PATH,
               width = 600, height = 300,
               background_color = 'white',
               mask = img,
               colormap='plamsa')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-8ba3ae47b36f> in <cell line: 0>()
#       3                width = 600, height = 300,
#       4                background_color = 'white',
# ----> 5                mask = img,
#       6                colormap='plamsa')
#
# NameError: name 'img' is not defined

# %%
img_worldcloud = wc.generate_from_frequencies(dic_word)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-46-14dc5cf636ef> in <cell line: 0>()
# ----> 1 img_worldcloud = wc.generate_from_frequencies(dic_word)
#
# /usr/local/lib/python3.11/dist-packages/wordcloud/wordcloud.py in generate_from_frequencies(self, frequencies, max_font_size)
#     451                 font_size = self.height
#     452             else:
# --> 453                 self.generate_from_frequencies(dict(frequencies[:2]),
#     454                                                max_font_size=self.height)
#     455                 # find font sizes
#
# /usr/local/lib/python3.11/dist-packages/wordcloud/wordcloud.py in generate_from_frequencies(self, frequencies, max_font_size)
#     504                     break
#     505                 # try to find a position
# --> 506                 font = ImageFont.truetype(self.font_path, font_size)
# ...

# %%
plt.figure(figsize = (6,4))
plt.axis('off')
plt.imshow(img_worldcloud)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-934716cfbae0> in <cell line: 0>()
#       1 plt.figure(figsize = (6,4))
#       2 plt.axis('off')
# ----> 3 plt.imshow(img_worldcloud)
#
# NameError: name 'img_worldcloud' is not defined

# %% [markdown]
# # BTS 기사 댓글 텍스트 마이닝

# %%
df = pd.read_csv('data/news_comment_BTS.csv',encoding='utf-8')
df
# Out:
#                  reg_time                                              reply  \
# 0     2020-09-01 22:58:09                                  국보소년단<U+0001F49C>
# 1     2020-09-01 09:56:46                                       아줌마가 들어도 좋더라
# 2     2020-09-01 09:08:06  팩트체크\n\n현재 빌보드 HOT 100\n\n1위  방탄소년단[BTS]\n2위 C...
# 3     2020-09-01 08:52:32            방탄소년단이 한국사람이라 너무 자랑스러워요 ㅠㅠ 우리오래오래 함께하자!
# 4     2020-09-01 08:36:33                대단한 BTS, 월드 클래스는 다르네^^ 좋은 소식!! 응원해요
# ...                   ...                                                ...
# 1195  2020-09-01 06:45:44                                     역시!!!!!!!!!!!!
# 1196  2020-09-01 06:45:05  우리 탄이들 너무 자랑스럽고\n사랑해<U+0001F49C><U+0001F49C><U...
# 1197  2020-09-01 06:40:15                             이런애들 꼭 군대를 보내 는게  맞을까요
# 1198  2020-09-01 06:38:56                                          군면제급이다 이건
# 1199  2020-09-01 06:34:59  자랑스러워요.정말   축하해 김남준 김석진 민윤기 정호석 박지민 김태형 전정국 BT...
#
# ...

# %%
df.head()
# Out:
#               reg_time                                              reply  \
# 0  2020-09-01 22:58:09                                  국보소년단<U+0001F49C>
# 1  2020-09-01 09:56:46                                       아줌마가 들어도 좋더라
# 2  2020-09-01 09:08:06  팩트체크\n\n현재 빌보드 HOT 100\n\n1위  방탄소년단[BTS]\n2위 C...
# 3  2020-09-01 08:52:32            방탄소년단이 한국사람이라 너무 자랑스러워요 ㅠㅠ 우리오래오래 함께하자!
# 4  2020-09-01 08:36:33                대단한 BTS, 월드 클래스는 다르네^^ 좋은 소식!! 응원해요
#
#   press                                  title  \
# 0  한국경제  [속보]BTS '다이너마이트', 한국 가수 최초로 빌보드 싱글 1위
# 1  한국경제  [속보]BTS '다이너마이트', 한국 가수 최초로 빌보드 싱글 1위
# 2  한국경제  [속보]BTS '다이너마이트', 한국 가수 최초로 빌보드 싱글 1위
# 3  한국경제  [속보]BTS '다이너마이트', 한국 가수 최초로 빌보드 싱글 1위
# 4  한국경제  [속보]BTS '다이너마이트', 한국 가수 최초로 빌보드 싱글 1위
#
#                                                  url
# 0  https://news.naver.com/main/read.nhn?mode=LSD&...
# 1  https://news.naver.com/main/read.nhn?mode=LSD&...
# 2  https://news.naver.com/main/read.nhn?mode=LSD&...
# ...

# %%
df['reply'][:10]
# Out:
# 0                                    국보소년단<U+0001F49C>
# 1                                         아줌마가 들어도 좋더라
# 2    팩트체크\n\n현재 빌보드 HOT 100\n\n1위  방탄소년단[BTS]\n2위 C...
# 3              방탄소년단이 한국사람이라 너무 자랑스러워요 ㅠㅠ 우리오래오래 함께하자!
# 4                  대단한 BTS, 월드 클래스는 다르네^^ 좋은 소식!! 응원해요
# 5                        정국오빠 생일과 더불어 빌보드 1위기사라니ㅠㅠ축제구나
# 6    정말 축하하고 응원하지만\n집에서 여러 계정으로 스트리밍 돌리고 사재기하고 다른 팬...
# 7                         기자는 자고 일어났지만, 팬들은 못자고 발표 기다림
# 8                                자랑스럽다!!!!!! 축하합니다!!!!
# 9                                 SuperM 늘 응원하고 사랑합니다~
# Name: reply, dtype: object

# %%
df['reply'] = df['reply'].str.replace('[^가-힣]',' ', regex = True)
df['reply']
# Out:
# 0                                       국보소년단
# 1                                            아줌마가 들어도 좋더라
# 2       팩트체크  현재 빌보드           위  방탄소년단       위       ...
# 3                 방탄소년단이 한국사람이라 너무 자랑스러워요    우리오래오래 함께하자
# 4                     대단한      월드 클래스는 다르네   좋은 소식   응원해요
#                               ...
# 1195                                       역시
# 1196    우리 탄이들 너무 자랑스럽고 사랑해                           ...
# 1197                               이런애들 꼭 군대를 보내 는게  맞을까요
# 1198                                            군면제급이다 이건
# 1199    자랑스러워요 정말   축하해 김남준 김석진 민윤기 정호석 박지민 김태형 전정국   ...
# Name: reply, Length: 1200, dtype: object

# %%
from konlpy.tag import Kkma
Kkma = Kkma()
Kkma.nouns(u'질문이나 건의사항은 깃헙 이슈 트래커에 남겨주세요.')
# Out:
# ['질문', '건의', '건의사항', '사항', '깃헙', '이슈', '트래커']

# %%
df2 = pd.DataFrame({'A':[1,2,3], 'B':[4,5,6]})
df2
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %%
df_s = df2.apply(lambda x : x**2)
df_s
# Out:
#    A   B
# 0  1  16
# 1  4  25
# 2  9  36

# %%
func = lambda x : x**2 #기말고사 예상문제
df_s = df2.apply(func)
df_s
# Out:
#    A   B
# 0  1  16
# 1  4  25
# 2  9  36

# %%
nouns = df['reply'].apply(Kkma.nouns)
nouns
# Out:
# 0                                        [국보, 국보소년단, 소년단]
# 1                                                   [아줌마]
# 2                   [팩트, 팩트체크, 체크, 보드, 위, 방탄, 방탄소년단, 소년단]
# 3              [방탄, 방탄소년단, 소년단, 한국, 한국사람, 사람, 자랑, 우리, 하자]
# 4                                       [월드, 클래스, 소식, 응원]
#                               ...
# 1195                                                   []
# 1196                                      [우리, 탄, 자랑, 사랑]
# 1197                                              [애, 군대]
# 1198                                     [군, 군면제급, 면제, 급]
# 1199    [자랑, 축하, 김, 김남, 남, 김석진, 민, 민윤기, 윤기, 정, 정호석, 호석...
# Name: reply, Length: 1200, dtype: object

# %%
df3 = pd.DataFrame({'A':[[0,1,2],'foo',[],[3,4]],
                    'B':1,
                    'C':[['a','b','c'],np.nan,[],['d','e']]})
df3
# Out:
#            A  B          C
# 0  [0, 1, 2]  1  [a, b, c]
# 1        foo  1        NaN
# 2         []  1         []
# 3     [3, 4]  1     [d, e]

# %%
df3.explode('A')
# Out:
#      A  B          C
# 0    0  1  [a, b, c]
# 0    1  1  [a, b, c]
# 0    2  1  [a, b, c]
# 1  foo  1        NaN
# 2  NaN  1         []
# 3    3  1     [d, e]
# 3    4  1     [d, e]

# %%
df3.explode(['A','C'])
# Out:
#      A  B    C
# 0    0  1    a
# 0    1  1    b
# 0    2  1    c
# 1  foo  1  NaN
# 2  NaN  1  NaN
# 3    3  1    d
# 3    4  1    e

# %%
type(nouns)
# Out:
# pandas.core.series.Series

# %%
nonus[:5]
# Out:
# 0       국보
# 0    국보소년단
# 0      소년단
# 1      아줌마
# 2       팩트
# Name: reply, dtype: object

# %%
nonus = nouns.explode()
nonus
# Out:
# 0          국보
# 0       국보소년단
# 0         소년단
# 1         아줌마
# 2          팩트
#         ...
# 1199      박지민
# 1199      김태형
# 1199        전
# 1199      전정국
# 1199       정국
# Name: reply, Length: 9353, dtype: object

# %%
nouns[0]
# Out:
# ['국보', '국보소년단', '소년단']

# %%
df_word = pd.DataFrame({'word': nonus})
df_word.head()
# Out:
#     word
# 0     국보
# 0  국보소년단
# 0    소년단
# 1    아줌마
# 2     팩트

# %%
df_word['len'] = df_word['word'].str.len()
df_word = df_word.query('len >= 2')
df_word.head()
# Out:
#     word  len
# 0     국보  2.0
# 0  국보소년단  5.0
# 0    소년단  3.0
# 1    아줌마  3.0
# 2     팩트  2.0

# %%
df_freq = df_word.groupby('word', as_index=False) \
            .agg(n = ('word', 'count')) \
            .sort_values('n', ascending=False)
df_freq
# Out:
#        word    n
# 752      방탄  280
# 1878     축하  236
# 1556     자랑  205
# 1032    소년단  144
# 763   방탄소년단  136
# ...     ...  ...
# 1136   실력있음    1
# 406    다음주면    1
# 1134     신화    1
# 1133     신중    1
# 1084    스을적    1
#
# [2168 rows x 2 columns]

# %%
top20 = df_freq.head(20)
top20
# Out:
#        word    n
# 752      방탄  280
# 1878     축하  236
# 1556     자랑  205
# 1032    소년단  144
# 763   방탄소년단  136
# 813      보드  131
# 618      면제  125
# 233     군면제   78
# 225      군대   77
# 1364     우리   68
# 11       가수   64
# 987      선양   62
# 215    국위선양   59
# 214      국위   58
# 328      나라   53
# 2038     한국   52
# 371      노래   50
# 463    대한민국   46
# 708      민국   46
# 462      대한   46

# %%
sns.barplot(top20, y='word', x='n', hue='word');

# %%
from PIL import image

icon = image.open('data/cloud.png')

img = image.new('RGB',icon.size, (255,255,255))
img.paste(icon,icon)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-107-fa5542bcfcff> in <cell line: 0>()
# ----> 1 from PIL import image
#       2
#       3 icon = image.open('data/cloud.png')
#       4
#       5 img = image.new('RGB',icon.size, (255,255,255))
#
# ImportError: cannot import name 'image' from 'PIL' (/usr/local/lib/python3.11/dist-packages/PIL/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
dic_word = df_freq.set_index('word').to_dict()['n']

# %%
dic_word
# Out:
# {'방탄': 280,
#  '축하': 236,
#  '자랑': 205,
#  '소년단': 144,
#  '방탄소년단': 136,
#  '보드': 131,
#  '면제': 125,
#  '군면제': 78,
#  '군대': 77,
#  '우리': 68,
#  '가수': 64,
#  '선양': 62,
#  '국위선양': 59,
#  '국위': 58,
#  '나라': 53,
#  '한국': 52,
#  '노래': 50,
#  '대한민국': 46,
#  '민국': 46,
#  '대한': 46,
#  '진짜': 43,
#  '최고': 40,
#  '대박': 39,
#  '세계': 36,
#  '아미': 35,
#  '소식': 31,
#  '시기': 30,
#  '생각': 30,
#  '정국': 29,
#  '사람': 29,
#  '라니': 29,
#  '행복': 29,
#  '사랑': 28,
#  '역사': 28,
#  '생일': 27,
#  '코로나': 27,
#  '차트': 27,
#  '핫백': 26,
#  '위라니': 24,
#  '감사': 24,
#  '축하해': 23,
#  '우리나라': 23,
#  '전세계': 22,
#  '그룹': 22,
#  '싱글': 22,
#  '미국': 22,
#  '이것': 22,
#  '진심': 22,
#  '인정': 22,
#  '정도': 22,
#  '노력': 21,
#  '응원': 20,
#  '요즘': 19,
#  '음악': 19,
#  '활동': 19,
#  '고생': 18,
#  '최초': 17,
#  '아이': 17,
#  '너희': 15,
#  '국가': 15,
#  '올림픽': 15,
#  '이제': 15,
#  '문화': 15,
#  '때문': 15,
#  '국민': 15,
#  '뉴스': 15,
#  '기분': 14,
#  '숟가락': 14,
#  '기사': 14,
#  '멤버': 14,
#  '수고': 14,
#  '대통령': 14,
#  '내가': 14,
#  '한국인': 13,
# ...

# %%
wc = WordCloud(random_state = 1234,
               font_path = FONT_PATH,
               width = 600, height = 300,
               background_color = 'white',
               mask = img,
               colormap='plamsa')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-110-8ba3ae47b36f> in <cell line: 0>()
#       3                width = 600, height = 300,
#       4                background_color = 'white',
# ----> 5                mask = img,
#       6                colormap='plamsa')
#
# NameError: name 'img' is not defined

# %%
img_worldcloud = wc.generate_from_frequencies(dic_word)

plt.figure(figsize=(6,4))
plt.axis('off')
plt.imshow(img_worldcloud)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-111-b96a7613b725> in <cell line: 0>()
# ----> 1 img_worldcloud = wc.generate_from_frequencies(dic_word)
#       2
#       3 plt.figure(figsize=(6,4))
#       4 plt.axis('off')
#       5 plt.imshow(img_worldcloud)
#
# /usr/local/lib/python3.11/dist-packages/wordcloud/wordcloud.py in generate_from_frequencies(self, frequencies, max_font_size)
#     451                 font_size = self.height
#     452             else:
# --> 453                 self.generate_from_frequencies(dict(frequencies[:2]),
#     454                                                max_font_size=self.height)
#     455                 # find font sizes
#
# /usr/local/lib/python3.11/dist-packages/wordcloud/wordcloud.py in generate_from_frequencies(self, frequencies, max_font_size)
#     504                     break
# ...

# %% [markdown]
# ## 종료
