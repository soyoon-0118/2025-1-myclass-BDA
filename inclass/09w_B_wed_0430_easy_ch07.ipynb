# %% [markdown]
# <a href="https://colab.research.google.com/github/soyoon-0118/2025-1-myclass-BDA/blob/main/inclass/09w_B_wed_0430_easy_ch07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.DataFrame({'sex': ["M", 'F', np.nan, 'M', 'F'],
                   'score': [5, 4, 3, 4, None]})
df
# Out:
#    sex  score
# 0    M    5.0
# 1    F    4.0
# 2  NaN    3.0
# 3    M    4.0
# 4    F    NaN

# %%
df.dropna(axis=1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
df.dropna(subset=['score'])
# Out:
#    sex  score
# 0    M    5.0
# 1    F    4.0
# 2  NaN    3.0
# 3    M    4.0

# %%
df.dropna(subset=['score'],axis=0)
# Out:
#    sex  score
# 0    M    5.0
# 1    F    4.0
# 2  NaN    3.0
# 3    M    4.0

# %%
df_nomiss=df.dropna(subset=['score'])
df_nomiss
# Out:
#    sex  score
# 0    M    5.0
# 1    F    4.0
# 2  NaN    3.0
# 3    M    4.0

# %%
df_nomiss['score']+1
# Out:
# 0    6.0
# 1    5.0
# 2    4.0
# 3    5.0
# Name: score, dtype: float64

# %%
df_nomiss=df.dropna(subset='score')
df_nomiss
# Out:
#    sex  score
# 0    M    5.0
# 1    F    4.0
# 2  NaN    3.0
# 3    M    4.0

# %%
df
# Out:
#    sex  score
# 0    M    5.0
# 1    F    4.0
# 2  NaN    3.0
# 3    M    4.0
# 4    F    NaN

# %%
df.score.mean()
# Out:
# np.float64(4.0)

# %%
df['score'].sum()
# Out:
# np.float64(16.0)

# %%
df.groupby('sex').agg(mean_score = ('score','mean'),sum_score = ('score','sum'))
# Out:
#      mean_score  sum_score
# sex
# F           4.0        4.0
# M           4.5        9.0

# %%
df= pd.DataFrame({"name":['alifred','Batman','Catwoman'],
                 "toy":[np.nan,'Batmobile','Bullwhip'],
                 "born":[np.nan,pd.Timestamp("1940-04-25"),pd.NaT]})
df
# Out:
#        name        toy       born
# 0   alifred        NaN        NaT
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT

# %%
df.dropna(how='any')
# Out:
#      name        toy       born
# 1  Batman  Batmobile 1940-04-25

# %%
df.isna()
# Out:
#     name    toy   born
# 0  False   True   True
# 1  False  False  False
# 2  False  False   True

# %%
df.dropna(axis=1)
# Out:
#        name
# 0   alifred
# 1    Batman
# 2  Catwoman

# %%
df.dropna(how='all')
# Out:
#        name        toy       born
# 0   alifred        NaN        NaT
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT

# %%
df.dropna(thresh=2)
# Out:
#        name        toy       born
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT

# %%
df.dropna(thresh=1)
# Out:
#        name        toy       born
# 0   alifred        NaN        NaT
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT

# %%
df.dropna(thresh=3)
# Out:
#      name        toy       born
# 1  Batman  Batmobile 1940-04-25

# %%
df.dropna(subset=['name','toy'])
# Out:
#        name        toy       born
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT

# %%
df.dropna(subset=['toy'])
# Out:
#        name        toy       born
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT

# %%
df.dropna(subset=['born'])
# Out:
#      name        toy       born
# 1  Batman  Batmobile 1940-04-25

# %% [markdown]
# ## 빈 데이터프레임 확인 방법

# %%
df1=pd.DataFrame(index=['row1','row2','row3'])
df1
# Out:
# Empty DataFrame
# Columns: []
# Index: [row1, row2, row3]

# %%
df1.empty
# Out:
# True

# %%
df2=pd.DataFrame(index=['col1','col2','col3'])
df2
# Out:
# Empty DataFrame
# Columns: []
# Index: [col1, col2, col3]

# %%
df2.empty
# Out:
# True

# %%
df3=pd.DataFrame(index=['col1','col2','col3'],columns=['row1','row2','row3'])
df3
# Out:
#      row1 row2 row3
# col1  NaN  NaN  NaN
# col2  NaN  NaN  NaN
# col3  NaN  NaN  NaN

# %%
df3.empty
# Out:
# False

# %%
df4=pd.DataFrame(np.nan,index=['col1','col2','col3'],columns=['row1','row2','row3'])
df4
# Out:
#       row1  row2  row3
# col1   NaN   NaN   NaN
# col2   NaN   NaN   NaN
# col3   NaN   NaN   NaN

# %%
df4.empty
# Out:
# False

# %%
df5=pd.DataFrame(2,index=['col1','col2','col3'],columns=['row1','row2','row3'])
df5
# Out:
#       row1  row2  row3
# col1     2     2     2
# col2     2     2     2
# col3     2     2     2

# %% [markdown]
# ## 결측값 대체

# %%
# !git clone https://github.com/ai7dnn/data
# Out:
# fatal: destination path 'data' already exists and is not an empty directory.

# %%
exam=pd.read_csv('data/exam.csv')
exam.loc[[2,7,14],['math']]=np.nan

exam
# Out:
#     id  nclass  math  english  science
# 0    1       1  50.0       98       50
# 1    2       1  60.0       97       60
# 2    3       1   NaN       86       78
# 3    4       1  30.0       98       58
# 4    5       2  25.0       80       65
# 5    6       2  50.0       89       98
# 6    7       2  80.0       90       45
# 7    8       2   NaN       78       25
# 8    9       3  20.0       98       15
# 9   10       3  50.0       98       45
# 10  11       3  65.0       65       65
# 11  12       3  45.0       85       32
# 12  13       4  46.0       98       65
# 13  14       4  48.0       87       12
# 14  15       4   NaN       56       78
# 15  16       4  58.0       98       65
# 16  17       5  65.0       68       98
# 17  18       5  80.0       78       90
# 18  19       5  89.0       68       87
# 19  20       5  78.0       83       58

# %%
exam.loc[[2,7,14],['math']]
# Out:
#     math
# 2    NaN
# 7    NaN
# 14   NaN

# %%
exam.loc[[2,7,14]]
# Out:
#     id  nclass  math  english  science
# 2    3       1   NaN       86       78
# 7    8       2   NaN       78       25
# 14  15       4   NaN       56       78

# %% [markdown]
# ## 결측값 채워넣기 fillna()

# %%
exam['math']=exam['math'].fillna(100)
exam.loc[[2,7,14]]
# Out:
#     id  nclass   math  english  science
# 2    3       1  100.0       86       78
# 7    8       2  100.0       78       25
# 14  15       4  100.0       56       78

# %%
exam['math']=exam['math'].fillna(exam['math'].mean())
exam.loc[[2,7,14]]
# Out:
#     id  nclass   math  english  science
# 2    3       1  100.0       86       78
# 7    8       2  100.0       78       25
# 14  15       4  100.0       56       78

# %%
pd.set_option('display.precision',2)
exam.loc[[2,7,14]]
# Out:
#     id  nclass   math  english  science
# 2    3       1  100.0       86       78
# 7    8       2  100.0       78       25
# 14  15       4  100.0       56       78

# %%
exam.math.isna().sum()
# Out:
# np.int64(0)

# %%
pd.set_option('display.precision',2)
exam.loc[[2,7,14]]
# Out:
#     id  nclass   math  english  science
# 2    3       1  100.0       86       78
# 7    8       2  100.0       78       25
# 14  15       4  100.0       56       78

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
aa = pd.DataFrame([1, 1, 2, 2])
aa
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-68-90974607b66b> in <cell line: 0>()
# ----> 1 aa = pd.DataFrame([1, 1, 2, 2])
#       2 aa
#
# TypeError: 'dict' object is not callable

# %%
df=pd.DataFrame([[1,1,2,2]])
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-2a359d43b6b3> in <cell line: 0>()
# ----> 1 df=pd.DataFrame([[1,1,2,2]])
#       2 df
#
# TypeError: 'dict' object is not callable

# %%
df = pd.DataFrame({'x1':[1,1,2,2]})
df['x2'] = np.where(df['x1']==1,10,np.nan)
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-61-a5e15742cd71> in <cell line: 0>()
# ----> 1 df = pd.DataFrame({'x1':[1,1,2,2]})
#       2 df['x2'] = np.where(df['x1']==1,10,np.nan)
#       3 df
#
# TypeError: 'dict' object is not callable

# %%
df.info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-62-a74c58233b9e> in <cell line: 0>()
# ----> 1 df.info()
#
# AttributeError: 'dict' object has no attribute 'info'

# %%
import pandas as pd
mpg = pd.read_csv('data/mpg.csv')
mpg.sample(10)
# Out:
#     manufacturer              model  displ  year  cyl       trans drv  cty  \
# 185       toyota              camry    3.5  2008    6    auto(s6)   f   19
# 61         dodge        durango 4wd    5.2  1999    8    auto(l4)   4   11
# 63         dodge        durango 4wd    5.9  1999    8    auto(l4)   4   11
# 190       toyota       camry solara    3.0  1999    6    auto(l4)   f   18
# 35     chevrolet             malibu    3.5  2008    6    auto(l4)   f   18
# 153       nissan     pathfinder 4wd    5.6  2008    8    auto(s5)   4   12
# 116      hyundai            tiburon    2.0  1999    4  manual(m5)   f   19
# 54         dodge  dakota pickup 4wd    4.7  2008    8    auto(l5)   4    9
# 9           audi         a4 quattro    2.0  2008    4  manual(m6)   4   20
# 232   volkswagen             passat    2.8  1999    6  manual(m5)   f   18
#
#      hwy fl    category
# 185   28  r     midsize
# 61    16  r         suv
# 63    15  r         suv
# 190   26  r     compact
# ...

# %%
mpg.describe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-74-c4b6cc23ae17> in <cell line: 0>()
# ----> 1 mpg.describe()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in describe(self, percentiles, include, exclude)
#   11974         max            NaN      3.0
#   11975         """
# > 11976         return describe_ndframe(
#   11977             obj=self,
#   11978             include=include,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/methods/describe.py in describe_ndframe(obj, include, exclude, percentiles)
#      95         )
#      96
# ---> 97     result = describer.describe(percentiles=percentiles)
#      98     return cast(NDFrameT, result)
#      99
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/methods/describe.py in describe(self, percentiles)
#     173
#     174         col_names = reorder_columns(ldesc)
# ...

# %%
import seaborn as sns
sns.boxplot(data = mpg, y = 'hwy')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-73-7f057258a335> in <cell line: 0>()
#       1 import seaborn as sns
# ----> 2 sns.boxplot(data = mpg, y = 'hwy');
#
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, dodge, width, gap, whis, linecolor, linewidth, fliersize, hue_norm, native_scale, log_scale, formatter, legend, ax, **kwargs)
#    1595 ):
#    1596
# -> 1597     p = _CategoricalPlotter(
#    1598         data=data,
#    1599         variables=dict(x=x, y=y, hue=hue),
#
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py in __init__(self, data, variables, order, orient, require_numeric, color, legend)
#      65     ):
#      66
# ---> 67         super().__init__(data=data, variables=variables)
#      68
# ...

# %%
s= pd.Series([1,2,3,4,5])
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
s.quantile([.01,.25,.50,.75,1])
# Out:
# 0.01    1.04
# 0.25    2.00
# 0.50    3.00
# 0.75    4.00
# 1.00    5.00
# dtype: float64

# %%
s.quantile(.50)
# Out:
# np.float64(3.0)

# %%
s.quantile()
# Out:
# np.float64(3.0)

# %%
s.quantile([.1,.25, .5, .75])
# Out:
# 0.10    1.4
# 0.25    2.0
# 0.50    3.0
# 0.75    4.0
# dtype: float64

# %%
mpg.hwy.describe()
# Out:
# count    234.00
# mean      23.44
# std        5.95
# min       12.00
# 25%       18.00
# 50%       24.00
# 75%       27.00
# max       44.00
# Name: hwy, dtype: float64

# %%
mpg.hwy.quantile([.25,.5,.75])
# Out:
# 0.25    18.0
# 0.50    24.0
# 0.75    27.0
# Name: hwy, dtype: float64

# %%
a,b=[10,20]

# %%
a
# Out:
# 10

# %%
b
# Out:
# 20

# %%
p25, p50, p75 = mpg.hwy.quantile([.25,.5,.75])

# %%
p25
# Out:
# 18.0

# %%
p50
# Out:
# 24.0

# %%
p75
# Out:
# 27.0

# %%
iqr = p75-p25

# %%
iqr
# Out:
# 9.0

# %% [markdown]
# ## upper fence

# %%
p25-1.5*iqr
# Out:
# 4.5

# %% [markdown]
# ## lower fence

# %%
p75+1.5*iqr
# Out:
# 40.5

# %%
mpg.hwy.describe()
# Out:
# count    234.00
# mean      23.44
# std        5.95
# min       12.00
# 25%       18.00
# 50%       24.00
# 75%       27.00
# max       44.00
# Name: hwy, dtype: float64

# %%
mpg.hwy.describe()['25%']
# Out:
# np.float64(18.0)

# %%
mpg.hwy.describe()['50%']
# Out:
# np.float64(24.0)

# %%
mpg.isna().sum()
# Out:
# manufacturer    0
# model           0
# displ           0
# year            0
# cyl             0
# trans           0
# drv             0
# cty             0
# hwy             0
# fl              0
# category        0
# dtype: int64

# %%
mpg['hwy'] = np.where((mpg['hwy'] < 4.5) | (mpg['hwy'] > 40.5), np.nan, mpg['hwy'])
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty   hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18  29.0  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21  29.0  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20  31.0  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21  30.0  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16  26.0  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...   ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19  28.0  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21  29.0  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16  26.0  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18  26.0  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17  26.0  p
#
#     category
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ...

# %%
len(mpg)
# Out:
# 234

# %%
dmpg=mpg.dropna(subset=['hwy'])
dmpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty   hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18  29.0  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21  29.0  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20  31.0  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21  30.0  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16  26.0  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...   ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19  28.0  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21  29.0  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16  26.0  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18  26.0  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17  26.0  p
#
#     category
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ...

# %%
dmpg.groupby('drv').agg(mean_hwy = ('hwy','mean'))
# Out:
#      mean_hwy
# drv
# 4       19.17
# f       27.73
# r       21.00

# %% [markdown]
# ## 7장 종료
